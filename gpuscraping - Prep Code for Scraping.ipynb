# %% [markdown]
# ##### Packages

# %%
import os
import re, string, unicodedata
from datetime import datetime
from dateutil import parser

import numpy as np
import pandas as pd

import collections
import requests
from urllib.request import urlopen
from bs4 import BeautifulSoup, NavigableString, Comment
#import imshow
# %matplotlib inline
import plotly
plotly.__version__

# %% [markdown]
# dd # Graphics Card Manufactuerers

# %%
# https://d1gzz21cah5pzn.cloudfront.net/img/websites/n/new/newegg.com-desktop@2x.1586873793.jpg

# %% [markdown]
# # Webscraping Selenium Preparation

# %%
with open(#'product_websites.txt') as file:
    bs = BeautifulSoup(pageSource, 'html.parser')
    

soup = BeautifulSoup('', "lxml") 
pageSource = driver.page_source

bs.find(id='content')

soup = BeautifulSoup(page)
bs = BeautifulSoup(pageSource, 'html.parser')
bs.find(id='content')

# %% [markdown]
# ## URL List

# %%
base_url_list = ["https://www.newegg.com/p/pl?N=100007709%20601292088%20601292090%204111%204112%204113%204114%204115%204814",
"https://www.newegg.com/p/pl?N=100007709%20601292088%20601292090%204111%204112%204113%204114%204115%204814&Page=2",
"https://www.newegg.com/p/pl?N=100007709%20601292088%20601292090%204111%204112%204113%204114%204115%204814&page=3",
"https://www.newegg.com/p/pl?N=100007709%20601292088%20601292090%204111%204112%204113%204114%204115%204814&page=4",
"https://www.newegg.com/p/pl?N=100007709%20601292088%20601292090%204111%204112%204113%204114%204115%204814&page=5",
"https://www.newegg.com/p/pl?N=100007709%20601292088%20601292090%204111%204112%204113%204114%204115%204814&page=6",
"https://www.newegg.com/p/pl?N=100007709%20601292088%20601292090%204111%204112%204113%204114%204115%204814&page=7",
"https://www.newegg.com/p/pl?N=100007709%20601292088%20601292090%204111%204112%204113%204114%204115%204814&page=8",      
"https://www.newegg.com/p/pl?N=100007709%20601292088%20601292090%204111%204112%204113%204114%204115%204814&page=9"]

# %%
test = 'https://www.newegg.com/asus-geforce-rtx-2080-ti-rog-strix-rtx2080ti-o11g-gaming/p/N82E16814126263?Item=N82E16814126263&quicklink=true'

regex = re.compile('^https://www.newegg.com/(.*?)(/{1})')
regex2 = re.compile('[^https://www.newegg.com/][a-zA-Z0-9]*-')
f = regex.search(test)
company_name = regex2.search(test)
f.group(1)

# %% [markdown]
# ## Download html for each video card link

# %%
soup = BeautifulSoup(driver.page_source, "lxml") 
pageSource = driver.page_source
bs = BeautifulSoup(pageSource, 'html.parser')
bs.find(id='content')
#print(bs.get_text())

# %%
lists1 = []
link1 = "https://www.newegg.com/asus-geforce-rtx-2080-ti-rog-strix-rtx2080ti-o11g-gaming/p/N82E16814126263?Item=N82E16814126263&quicklink=true"
lists1.append(link1)
import requests
from bs4 import BeautifulSoup
#url
# soup = BeautifulSoup(html)
# print(soup.prettify())

def get_soups(links_list, names='a'):
    count=1
    for i in links_list:
        page = urllib.request.urlopen(i).read()
        soup = BeautifulSoup(page)
        pageName = "./listings/" + names + str(count) +".txt"
        urllib.request.urlretrieve(i, pageName)
        count +=1
get_soups(lists1)

lists1



souplist = []

#Specs > fieldset:nth-child(1)
for i in range(1,9):
    path = "./listings/" + str(i) +".txt"
    f= open(path)
    text = f.read()
    bs = BeautifulSoup(text, 'lxml')
    souplist.append(bs)

# fields = [f for f in souplist 
temp = souplist[1].find('fieldset')

# table.find("price")

# [type(item) for item in list(souplist[0].children)]
element.get_attribute('innerHTML')

# %%
#DOWNLOAD For indivudal Products

def get_soups_product(links_list):
    count=1
    opener = urllib.request.build_opener()
    opener.addheaders = [('User-agent', 'Mozilla/5.0 (Window NT 6.1; WOW64; rv:56.0) Gecko/20100101 Firefox/56.0')]
    urllib.request.install_opener(opener)
    
    for i in links_list:
        prod = i.split('/')
        try:
            page = urllib.request.urlopen(i).read()
        except:
            continue
        path = "./product_downloads/" + prod[3] + '_' + str(count) + ".txt"
        urllib.request.urlretrieve(i, path)
        count +=1

get_soups_product(flat_plist)

# %%
#requests the page with BeautifulSoup and appends the soup objects to a list. 
#Let’s call this function get_soups(links_list)

#souptemp = BeautifulSoup(content, "lxml")

def get_soups(links_list, names='a'):
    count=1
    for i in links_list:
        page = urllib.request.urlopen(i).read()
        pageName = "./listings/" + str(count) +".txt"
        urllib.request.urlretrieve(i, pageName)
        count +=1

get_soups(base_url_list)

headers = {'user-agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/13.0 Safari/605.1.15'}

# %% [markdown]
# ## Get txt file to Beautiful Soup
#
# * Code below was used to download all html

# %%
soup = BeautifulSoup(content, 'lxml').findAll(['a', {'class': 'item-img'},'a', {'class': 'item-brand'}])
soup

# %% [markdown]
# ## Extract indivdual product links
# ## Download the gpu lists pages (overview of gpus page 1 to x)

# %%
#Download the items list page
product_links = {}
print(os.getcwd())
for url in base_url_list:
    content = urllib.request.urlopen(url).read()
    for link in BeautifulSoup(content, 'lxml').findAll('a', {'class': 'item-img'}):
        print(link['href'])
        temp = regex.search(link['href'])
        temp2 = regex2.search(link['href'])
        company = temp2
        product_name = temp.group(1)
        href = link['href']
        product_links[product_name] = href
        
        
product_links

# response = requests.get(base_url, headers=headers)
# text = BeautifulSoup(response.text, 'html.parser')

# %%
test = 'https://www.newegg.com/asus-geforce-rtx-2080-ti-rog-strix-rtx2080ti-o11g-gaming/p/N82E16814126263?Item=N82E16814126263&quicklink=true'

#Clean links for use in selenium
regex = re.compile('^https://www.newegg.com/(.*?)(/{1})')
regex2 = re.compile('[^https:\/\/www\.newegg\.com\/][a-zA-Z0-9]*-')
f = regex.search(test)
company_name = regex2.search(test)
f.group(1)

# %%
# writer = csv.writer(csv_file)
with open('productlinks.csv', 'w', encoding='utf-8') as file:
    for r in product_links.values():
        print(r)
        r.strip()
        wr = csv.writer(file)
        wr.writerow([r])
        
    file.close()

# %%
last_start = 64
flat_plist[last_start]
flat_plist.index('https://www.newegg.com/asus-geforce-rtx-2080-super-dual-rtx2080s-o8g-evo/p/N82E16814126335?Item=N82E16814126335')

# %%
len(product_links)

# %%
base_url = 'https://www.newegg.com/asus-geforce-rtx-2080-ti-rog-strix-rtx2080ti-o11g-gaming/p/N82E16814126263?Item=N82E16814126263'
prod = base_url.split('/')
company = prod[3].split('-')[0]
product = prod[3].replace('-',' ')
print(product)
print(company)

# %% [markdown]
#  # Total Products Sampled
#  ### 119
#
#
# ### Total Reviews
# #### ??

# %% [markdown]
# ## Challenges
#
# ### 1. Some reviews were in different languages

# %% [markdown]
# <p><a name="DP"></a></p>
#
#
# ## Sections
#
# - <a href="#DP">Data Preparation</a><br>
# - <a href="#sections">Home</a><br>
#
# - <a href="#miss">Handling Missing Data</a><br>
# - <a href="#grouping">Grouping and aggregration</a><br>
# - <a href="#time">Time Series</a><br>
# - <a href="#sol">Solutions</a><br>

# %% [markdown]
# # Exploration of Review Data

# %%
from wordcloud import WordCloud
wordcloud = WordCloud(height=2000, width=2000, background_color='white')
wordcloud = wordcloud.generate(' '.join(df1['Cleaned_Rev'].tolist()))
plt.imshow(wordcloud)
plt.title("Most common words in the reviews")
plt.axis('off')
plt.show()

# %%
df.sample(5)

# %%
df.Company.describe()

# %%
df.Price.describe()

# %%
df.Customer.describe()

# %%
df1['Review']=df1['Review'].apply(lambda x:x.strip('\n'))
df1.head(10)

# %% [markdown]
# ### Datatypes of Columns and Descriptions

# %%
data_types = pd.DataFrame(df.dtypes,
        columns=['Data Type'])
data_types

# %%
missing_data_counts = pd.DataFrame(df.isnull().sum(), columns=['Missing Values'])
missing_data_counts

# %%
present_data_counts = pd.DataFrame(df.count(),columns=['Present Values'])
present_data_counts

# %%
unique_value_counts = pd.DataFrame(
        columns=['Unique Values'])
for v in list(df.columns.values):
        unique_value_counts.loc[v] = [df[v].nunique()]
unique_value_counts

# %%
#max
maximum_values = pd.DataFrame(
        columns=['Maximum Values'])
for v in list(df.columns.values):
        maximum_values.loc[v] = [df[v].max()]
maximum_values

# %%
pd.concat([present_data_counts,
        missing_data_counts,
        unique_value_counts,
        minimum_values,
        maximum_values],
        axis=1)

# %%
bdf1.head(3)

# %%
# myFile =  open('productreviews_all.csv', 'w', encoding='utf-8',newline='')
# # myFile =  open('productreviews1.csv', 'w', encoding='utf-8',newline='')
# writer = csv.writer(myFile, delimiter=',', quotechar='"')

# %%
#product, prices, specs
f1 = open('product_websites.txt', 'r')
# soupy = f.read()
filetext = f1

# %%
cs = BeautifulSoup(f1,'lxml')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-21084bfe4bc4> in <module>
# ----> 1 cs = BeautifulSoup(f1,'lxml')
#
# NameError: name 'BeautifulSoup' is not defined

# %%
type(cs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-9616c63868c8> in <module>
# ----> 1 type(cs)
#
# NameError: name 'cs' is not defined

# %%
# # soupy = f.read()
# filetext = f1
#spec2 = cs.find_all('fieldset')
specval2= cs.find_all('dd')
sv = cs.find_all('dt')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-bf14e39fef2f> in <module>
#       2 # filetext = f1
#       3 #spec2 = cs.find_all('fieldset')
# ----> 4 specval2= cs.find_all('dd')
#       5 sv = cs.find_all('dt')
#
# NameError: name 'cs' is not defined

# %%
spec2
# Out:
# [<fieldset class="special-offers" id="autoAddComboGiftContent" style="display: none;">\n          </fieldset>,
#  <fieldset>\n             <h3 class="specTitle">\n              Model\n             </h3>\n             <legend style="display:none;">\n              |\n             </legend>\n             <dl>\n              <dt>\n               Brand\n              </dt>\n              <dd>\n               ASUS\n              </dd>\n             </dl>\n             <dl>\n              <dt>\n               Series\n              </dt>\n              <dd>\n               ROG Strix\n              </dd>\n             </dl>\n             <dl>\n              <dt>\n               Model\n              </dt>\n              <dd>\n               ROG-STRIX-RTX2080TI-O11G-GAMING\n              </dd>\n             </dl>\n            </fieldset>,
# ...

# %%
cs.prettify()

# %%
# print(spec2.get_text())
keys = ['Brand']

# specval2
text
listz = []
for i in spec2: 
    z = i.get_text(";", strip=True).strip().strip('\\n')
    z = re.sub(r'[\W\.\s\n]+',' ',z)
    z = re.sub(r'[\W\.\s\n]',' ',z)
    listz.append(z)


# newmsg = newmsg + "\n" + ' '.join(line.split())

# %%
listz

# %%
re.sub(r'[\W\.\s\n]',' ',listz[1])

# %%
x =[' ASUS',
 ' ROG Strix',
 ' ROG STRIX RTX2080TI O11G GAMING',
 ' PCI Express 3 0',
 ' NVIDIA',
 ' GPU Series',
 ' NVIDIA GeForce RTX 20 Series',
 ' n GPU n ',
 ' GeForce RTX 2080 Ti',
 ' n Core Clock n ',
 ' 1350 MHz',
 ' n Boost Clock n ',
 ' OC Mode 1665 MHz n n Gaming Mode 1650 MHz',
 ' n CUDA Cores n ',
 ' 4352',
 ' n Effective Memory Clock n ',
 ' 14000 MHz',
 ' Memory Size',
 ' 11GB',
 ' n Memory Interface n ',
 ' 352 Bit',
 ' Memory Type',
 ' GDDR6']

len(x)

# %%
# a_tag = cs.a

# # i_tag = cs.dt.extract()

for i in spec2:
    [print(text) for text in i.stripped_strings]

# dt1 = cs..extract()


# # print(i_tag.parent)

# # my_string = i_tag.string.extract()
# my_string
# # u'example.com'

# i_tag
# # <i></i>

# %%
for i in sv:
    print(unicode(i.a))

# %%
for word in words:
    word_processed = word.lower()
    word_processed = word_processed.strip(punctuation)
    if word_processed in positive_words:
        print word + ' is a positive word'

# %%
def get_products(spec2,specval2,prod_list):
    for x, y in zip(spec2,specval2):
        x = x.get_text()
        y = y.get_text()
#         x.split()
#         y.split()
        z = x.strip(',') + y.strip(',')
        print(z)
        prod_list.append(z)#[x,y]
    print('done')
    return prod_list
# import numpy as np 
  
# # function to get unique values 
# def makeunique(list1): 
#     x = np.array(list1) 
#     return x 
def makeclean(list2):
    temp = []
    temp = list2
    for i in temp:
        i[0]= re.sub(r'[n\W\s]\W+(\\n)*', '',i[0])
        i[1] = re.sub(r'[n\W\s]\W+(\\n)*', '',i[1])
    return temp
# get_text(' ', strip = True)

# %%
list_new = makeclean(get_products(spec2,specval2,prod_list))
# print(list_new)

# %%
list_new

# list2 = []
# for i in list_new:
#    print(i)

# %%
a = list_new[1:5][1][1]
print(a)

# %%
a = list_new[1:5]
print(a)

# %%
import csv

# ['Brand']

with open('product_clean.csv', 'w') as f:
    write = csv.writer(f)
    for i in prod_list:
        print(i)
        write.writerow(i)

# %%
# spec = []
# specval = []
# for i in spec:
#     i.text.replace('\n','').strip().lower()
#     i.re.sub(' +', ' ')
#     spec.append(i)
    
s1 = spec
s2 = specval

# %%
spec = []
specval = []

# for i in specval:
#     i.text.replace('\n','').strip().lower()
#     i.re.sub(' +', ' ')
#     specval.append(i)

# %%
spec_dict = {}
spec_dict['username'] = username
writer.writerow((spec_dict.values()))
# list1 = spec + specval
    spec_dict[x.text.strip()] = y.text.strip()
for x, y in zip(spec,specval):
    spec_dict['username'] = username
    writer.writerow((spec_dict.values()))

# %%
import csv
with open('product_clean.csv', 'w') as f:
    write = csv.writer(f)
    write.writerow(['Spec', 'Value'])
    
    for keys, values in spec_dict:
        write.writerow([keys.replace('\n',''),values.replace('\n','')])

dict(list(spec_dict.items())[0:2])

# %%
# from bs4 import SoupStrainer
# # for string in bs.stripped_strings:
# #     print(repr(string))

# # only_fields = find_all('div',id='Specs')

# print(only_fields)

# type(bs)

# #     print('writing done') 
# # bs.find_all()
# # dt = bs.find_all('dt')

# %%
 result = []
for zt in spec:
    print(zt)

# %%
#dt.contents
s = bs.find_all('div',id='Specs')
# fields = [f for f in souplist 
fields1 = bs.find_all('fieldset')

# %%
new_text = []
for i in s:
    ptext = i.get_text('; ', strip = True)
    new_text.append(ptext.strip().replace('\n',''))

# %%
prodcode = temp
prod_list = []
for r in prodcode:
    x = r.get_text()
    print(x)
    prod_list.append(x)

# %%
fun = []
xt = fields1.prettify()
print(xt)

# %%
temp = s.find_all('h3', class_='specTitle')

# %%
prodcode = temp
prod_list = []
for r in prodcode:
    x = r.get_text()
    print(x)
    prod_list.append(x)

# %%
file = open("parseddata.txt", "wb")

for link in soup.find_all('img'):
    print  link.get('src')
    file.write(link.get('src')+"\n")

file.flush()
file.close()
# os.chdir('c:/Users/danie/Python Files/NYCDSA/gpuscraper-project')
# BeautifulSoup('')
